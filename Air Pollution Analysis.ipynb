# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('city_day.csv')
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %%
file_path = 'city_day.csv'
data = pd.read_csv(file_path)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data_cleaned = data.dropna(subset=['City', 'AQI'])

# %%
city_aqi_median = data_cleaned.groupby('City')['AQI'].median().sort_values(ascending=False)
print(city_aqi_median)
# Out:
# City
# Ahmedabad             384.5
# Delhi                 257.0
# Patna                 215.0
# Gurugram              208.0
# Lucknow               198.0
# Jorapokhar            133.0
# Talcher               128.5
# Brajrajnagar          122.0
# Jaipur                122.0
# Bhopal                120.0
# Visakhapatnam         106.0
# Hyderabad             104.0
# Amritsar              101.0
# Chennai               100.0
# Kochi                  99.0
# Guwahati               98.0
# Ernakulam              94.0
# Kolkata                94.0
# Mumbai                 91.0
# Bengaluru              86.0
# Chandigarh             82.0
# Amaravati              78.0
# Coimbatore             75.0
# Thiruvananthapuram     68.0
# Shillong               48.0
# Aizawl                 23.0
# Name: AQI, dtype: float64

# %%
city_aqi_mean = data_cleaned.groupby('City')['AQI'].mean().sort_values(ascending=False)
print(city_aqi_mean)
# Out:
# City
# Ahmedabad             452.122939
# Delhi                 259.487744
# Patna                 240.782042
# Gurugram              225.123882
# Lucknow               217.973059
# Talcher               172.886819
# Jorapokhar            159.251621
# Brajrajnagar          150.280505
# Kolkata               140.566313
# Guwahati              140.111111
# Jaipur                133.679159
# Bhopal                132.827338
# Amritsar              119.920959
# Visakhapatnam         117.269855
# Chennai               114.502654
# Hyderabad             109.207447
# Mumbai                105.352258
# Kochi                 104.284810
# Chandigarh             96.498328
# Amaravati              95.299643
# Bengaluru              94.318325
# Ernakulam              92.359477
# Thiruvananthapuram     75.878327
# Coimbatore             73.023256
# Shillong               53.795122
# Aizawl                 34.765766
# Name: AQI, dtype: float64

# %%
data_cleaned = data.dropna(subset=['City', 'AQI_Bucket'])

# %%
city_aqi_bucket_counts = data_cleaned.groupby('City')['AQI_Bucket'].value_counts()
print(city_aqi_bucket_counts.to_string())
# Out:
# City                AQI_Bucket
# Ahmedabad           Severe           638
#                     Poor             238
#                     Very Poor        216
#                     Moderate         198
#                     Satisfactory      43
#                     Good               1
# Aizawl              Good              83
#                     Satisfactory      28
# Amaravati           Satisfactory     409
#                     Moderate         219
#                     Good             158
#                     Poor              47
#                     Very Poor          8
# Amritsar            Satisfactory     473
#                     Moderate         448
#                     Good              84
#                     Poor              67
#                     Very Poor         47
#                     Severe             7
# Bengaluru           Satisfactory    1124
#                     Moderate         630
#                     Good             115
#                     Poor              36
#                     Very Poor          5
# Bhopal              Moderate         165
#                     Satisfactory      76
#                     Poor              31
#                     Very Poor          4
#                     Good               2
# Brajrajnagar        Moderate         421
#                     Satisfactory     122
#                     Poor             120
#                     Very Poor         36
#                     Good              14
# Chandigarh          Satisfactory     154
#                     Moderate          74
#                     Good              48
#                     Poor              20
#                     Very Poor          3
# Chennai             Satisfactory     941
#                     Moderate         804
#                     Poor             110
#                     Good              12
#                     Very Poor         11
#                     Severe             6
# Coimbatore          Satisfactory     288
#                     Good              43
#                     Moderate          13
# Delhi               Poor             542
#                     Very Poor        520
#                     Moderate         519
#                     Severe           239
#                     Satisfactory     158
#                     Good              21
# Ernakulam           Satisfactory     104
#                     Moderate          49
# Gurugram            Moderate         454
#                     Very Poor        348
#                     Poor             310
#                     Satisfactory     225
#                     Severe            95
#                     Good              21
# Guwahati            Satisfactory     135
#                     Good             116
#                     Moderate         111
#                     Poor              69
#                     Very Poor         59
#                     Severe             5
# Hyderabad           Moderate         958
#                     Satisfactory     710
#                     Good             141
#                     Poor              54
#                     Very Poor         10
#                     Severe             7
# Jaipur              Moderate         651
#                     Satisfactory     317
#                     Poor             110
#                     Very Poor         10
#                     Good               4
#                     Severe             2
# Jorapokhar          Moderate         451
#                     Satisfactory     137
#                     Poor             121
#                     Very Poor         34
#                     Severe            18
#                     Good              10
# Kochi               Satisfactory      82
#                     Moderate          74
#                     Poor               2
# Kolkata             Satisfactory     285
#                     Moderate         152
#                     Good             119
#                     Poor             119
#                     Very Poor         66
#                     Severe            13
# Lucknow             Moderate         578
#                     Very Poor        473
#                     Satisfactory     365
#                     Poor             352
#                     Severe           110
#                     Good              15
# Mumbai              Satisfactory     428
#                     Moderate         285
#                     Poor              35
#                     Good              26
#                     Very Poor          1
# Patna               Moderate         507
#                     Very Poor        371
#                     Poor             236
#                     Severe           174
#                     Satisfactory     171
# Shillong            Good             111
#                     Satisfactory      84
#                     Moderate          10
# Talcher             Moderate         324
#                     Satisfactory     150
#                     Very Poor         97
#                     Poor              84
#                     Severe            24
#                     Good              19
# Thiruvananthapuram  Satisfactory     768
#                     Moderate         154
#                     Good             126
#                     Poor               4
# Visakhapatnam       Moderate         580
#                     Satisfactory     447
#                     Poor              74
#                     Good              52
#                     Very Poor         18

# %%
avg_2_5 = data.groupby('City')['PM2.5'].mean()

# %%
avg_2_5
# Out:
# City
# Ahmedabad              67.854497
# Aizawl                 17.130000
# Amaravati              37.773217
# Amritsar               55.468335
# Bengaluru              35.819828
# Bhopal                 50.059571
# Brajrajnagar           64.057610
# Chandigarh             41.130242
# Chennai                50.425613
# Coimbatore             29.151587
# Delhi                 117.196153
# Ernakulam              24.944747
# Gurugram              117.104007
# Guwahati               63.685429
# Hyderabad              47.035357
# Jaipur                 54.500708
# Jorapokhar             64.228918
# Kochi                  31.428519
# Kolkata                64.362833
# Lucknow               109.714059
# Mumbai                 35.198393
# Patna                 123.498562
# Shillong               30.823984
# Talcher                61.405425
# Thiruvananthapuram     28.036617
# Visakhapatnam          46.969610
# Name: PM2.5, dtype: float64

# %%
plt.figure(figsize=(12, 6))
avg_2_5.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Average PM2.5 Levels by City', fontsize=14)
plt.xlabel('City', fontsize=12)
plt.ylabel('PM2.5 Level', fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pollutants = ['PM2.5', 'PM10', 'NO2', 'CO', 'SO2', 'O3']
def visualize_air_quality_distribution_stats(data_cleaned, pollutants):
    while True:
        print("\nAvailable pollutants to visualize:")
        for idx, pollutant in enumerate(pollutants, start=1):
            print(f"{idx}. {pollutant}")

        try:
            choice_pollutant = int(input(f"\nEnter the number corresponding to the pollutant you want to visualize (1-{len(pollutants)}): "))
            if choice_pollutant < 1 or choice_pollutant > len(pollutants):
                print("Invalid choice. Please select a valid number.")
                continue

            selected_pollutant = pollutants[choice_pollutant - 1]
            print("\nAvailable statistics:")
            print("1. Mean")
            print("2. Median")
            print("3. Standard Deviation")
            print("4. Maximum")
            print("5. Minimum")

            choice_stat = int(input(f"Enter the number corresponding to the statistic you want to use (1-5): "))
            if choice_stat < 1 or choice_stat > 5:
                print("Invalid choice. Please select a valid number.")
                continue
            stat_functions = {
                1: 'mean',
                2: 'median',
                3: 'std',
                4: 'max',
                5: 'min'
            }
            stat_func = stat_functions[choice_stat]
            stat_value = getattr(data_cleaned[selected_pollutant], stat_func)()
            print(f"\n{stat_func.capitalize()} of {selected_pollutant}: {stat_value}")
            plt.figure(figsize=(10, 6))
            sns.histplot(data_cleaned[selected_pollutant], bins=30, kde=True, color='blue')
            plt.title(f'Distribution of {selected_pollutant} (Statistic: {stat_func.capitalize()})', fontsize=14)
            plt.xlabel(f'{selected_pollutant} Levels', fontsize=12)
            plt.ylabel('Frequency', fontsize=12)
            plt.tight_layout()
            plt.show()

        except ValueError:
            print("Invalid input. Please enter a valid number.")

        # Ask the user if they want to continue or exit
        continue_choice = input("\nDo you want to analyze another pollutant? (yes/no): ").strip().lower()
        if continue_choice != 'yes':
            print("Exiting the program. Goodbye!")
            break
data = {
    'PM2.5': [12, 15, 18, 13, 14, 20, 21],
    'PM10': [30, 35, 40, 45, 50, 55, 60],
    'NO2': [30, 25, 20, 22, 28, 35, 40],
    'CO': [0.5, 0.8, 0.7, 0.9, 1.0, 1.1, 1.2],
    'SO2': [0.03, 0.02, 0.04, 0.03, 0.05, 0.06, 0.07],
    'O3': [100, 110, 120, 130, 125, 115, 105]
}

data_cleaned = pd.DataFrame(data)
visualize_air_quality_distribution_stats(data_cleaned, pollutants)
# Out:
# Available pollutants to visualize:
# 1. PM2.5
# 2. PM10
# 3. NO2
# 4. CO
# 5. SO2
# 6. O3
# Enter the number corresponding to the pollutant you want to visualize (1-6):  1
# Available statistics:
# 1. Mean
# 2. Median
# 3. Standard Deviation
# 4. Maximum
# 5. Minimum
# Enter the number corresponding to the statistic you want to use (1-5):  4
# Max of PM2.5: 21
# Do you want to analyze another pollutant? (yes/no):  no
# Exiting the program. Goodbye!

# %%
print(data_cleaned.columns)
# Out:
# Index(['PM2.5', 'PM10', 'NO2', 'CO', 'SO2', 'O3'], dtype='object')

# %%
data_cleaned['AQI'] = (data_cleaned['PM2.5'] + data_cleaned['PM10'])

# %%
sns.histplot(data_cleaned['AQI'], bins=30, kde=True, color='purple')
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
print(data_cleaned.columns)
if 'AQI' in data_cleaned.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(data_cleaned['AQI'], bins=30, kde=True, color='purple')
    plt.title('Distribution of AQI Levels', fontsize=14)
    plt.xlabel('AQI', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.tight_layout()
    plt.show()
else:
    print("Error: 'AQI' column not found in the dataset.")
# Out:
# Index(['PM2.5', 'PM10', 'NO2', 'CO', 'SO2', 'O3', 'AQI'], dtype='object')

# %%
bucket_counts = df['AQI_Bucket'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=bucket_counts.index, y=bucket_counts.values, palette="viridis", hue=None)
plt.title('Distribution of Air Quality Buckets', fontsize=14)
plt.xlabel('AQI Bucket', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17052\3107491701.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bucket_counts.index, y=bucket_counts.values, palette="viridis", hue=None)

# %%
import pandas as pd
data = {
    'City': ['Ahmedabad', 'Aizwal', 'Amaravathi', 'Amritsar', 'Bengaluru', 'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',],
    'AQI': [50, 120, 150, 180, 90, 200, 60, 75, 300, 400]
}
data_cleaned = pd.DataFrame(data)
bins = [0, 50, 100, 150, 200, 300, 500]
labels = ['good', 'moderate', 'satisfactory', 'poor', 'very poor', 'severe']
data_cleaned['AQI_Bucket'] = pd.cut(data_cleaned['AQI'], bins=bins, labels=labels, right=False)
def show_cities_in_aqi_bucket(data_cleaned, labels):
    while True:
        print("\nAvailable AQI Buckets:")
        for idx, label in enumerate(labels, start=1):
            print(f"{idx}. {label}")
        
        try:
            choice_bucket = int(input(f"\nEnter the number corresponding to the AQI bucket (1-{len(labels)}): "))
            if choice_bucket < 1 or choice_bucket > len(labels):
                print("Invalid choice. Please select a valid number.")
                continue
            
            selected_bucket = labels[choice_bucket - 1]
            cities_in_bucket = data_cleaned[data_cleaned['AQI_Bucket'] == selected_bucket]['City']
            if not cities_in_bucket.empty:
                print(f"\nCities with AQI bucket '{selected_bucket}':")
                for city in cities_in_bucket:
                    print(city)
            else:
                print(f"No cities found in the '{selected_bucket}' AQI bucket.")
        
        except ValueError:
            print("Invalid input. Please enter a valid number.")
        continue_choice = input("\nDo you want to check another AQI bucket? (yes/no): ").strip().lower()
        if continue_choice != 'yes':
            print("Exiting the program. Goodbye!")
            break
show_cities_in_aqi_bucket(data_cleaned, labels)
# Out:
# Available AQI Buckets:
# 1. good
# 2. moderate
# 3. satisfactory
# 4. poor
# 5. very poor
# 6. severe
# Enter the number corresponding to the AQI bucket (1-6):  3
# Cities with AQI bucket 'satisfactory':
# Aizwal
# Do you want to check another AQI bucket? (yes/no):  yes
# Available AQI Buckets:
# 1. good
# 2. moderate
# 3. satisfactory
# 4. poor
# 5. very poor
# 6. severe
# Enter the number corresponding to the AQI bucket (1-6):  5
# Cities with AQI bucket 'very poor':
# Bhopal
# Do you want to check another AQI bucket? (yes/no):  no
# Exiting the program. Goodbye!
